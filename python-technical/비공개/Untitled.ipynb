# %%
import pandas as pd
from pandas import DataFrame

# %%
df = pd.read_excel("E:/jhp/200101_200630_테스트.xls")

# %%
df['혈액검사결과']
# Out:
# 0       Hb   9.4  Hct   28.4  WBC   12.16  Platelet   ...
# 1       Hb   17.1  Hct   49.4  WBC   8.65  Platelet   ...
# 2       Hb   11.0  Hct   34.0  WBC   7.49  Platelet   ...
# 3       Hb   15.7  Hct   47.0  WBC   7.31  Platelet   ...
# 4       Hb   15.4  Hct   43.6  WBC   8.40  Platelet   ...
#                               ...
# 1375    Hb   11.1  Hct   32.8  WBC   7.60  Platelet   ...
# 1376    Hb   15.3  Hct   46.1  WBC   7.64  Platelet   ...
# 1377    Hb   13.2  Hct   40.8  WBC   7.19  Platelet   ...
# 1378    Hb   12.9  Hct   38.3  WBC   5.89  Platelet   ...
# 1379    Hb   12.4  Hct   36.6  WBC   7.35  Platelet   ...
# Name: 혈액검사결과, Length: 1380, dtype: object

# %%
df['혈액검사결과'].str.extract("\w+")

# %%
df['혈액검사결과'].str.split().to_dict()
# Out:
# {0: ['Hb',
#   '9.4',
#   'Hct',
#   '28.4',
#   'WBC',
#   '12.16',
#   'Platelet',
#   '251',
#   'S-glucose',
#   '135',
#   'Na',
#   '141',
#   'K',
#   '4.2',
#   'Cl',
#   '106',
#   'BUN',
#   '19.1',
#   'Cr',
#   '0.61',
#   'AST',
#   '19',
#   'ALT',
#   '17',
#   'Protein',
#   '5.9',
#   'Albumin',
#   '3.4',
#   'Total',
#   'bilirubin',
#   '0.28',
#   'T3',
#   '89.0',
#   'T4',
#   'TSH',
#   '5.03',
#   'Free',
#   'T4',
#   '1.17',
#   'PT',
#   '10.6',
#   'PTT',
#   '31.7',
#   'INR',
#   '0.93',
#   'BT',
#   'CT',
#   'pH',
#   'PCO₂',
#   'PO₂',
#   'BE',
#   'SaO₂',
#   'HBs',
#   'Ab',
#   'Positive',
#   'HBs',
#   'Ag',
#   'Negative',
#   'HCV',
#   'Ab',
#   'Negative',
#   'HIV',
#   'Ab',
#   'Negative',
#   'VDRL',
#   'Non',
#   'Reactive'],
#  1: ['Hb',
#   '17.1',
#   'Hct',
#   '49.4',
#   'WBC',
#   '8.65',
#   'Platelet',
#   '212',
#   'S-glucose',
#   '97',
#   'Na',
#   '142',
#   'K',
#   '3.9',
#   'Cl',
#   '104',
#   'BUN',
#   '8.2',
# ...
